# %% [markdown]
# # 01 — Isotropy diagnostics (plotting only)
#
# Reads `results/phase1/*.parquet` produced by `scripts/phase1_isotropy.py` and renders the
# Phase 2 figures (Shapiro-Wilk p-value histogram, Epps-Pulley histogram, per-dimension variance
# bar chart). See `docs/spec.md` Phase 2. Stub at Phase 0.
