# %% [markdown]
# # 05 — Pareto plots and per-class failure modes (plotting only)
#
# Reads `results/phase5/pareto.parquet` and renders per-task Pareto plots, the rank-normalised
# aggregate plot, and the per-class F1 table. See `docs/spec.md` Phase 6. Stub at Phase 0.
