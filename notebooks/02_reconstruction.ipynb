# %% [markdown]
# # 02 — Reconstruction quality vs k (plotting only)
#
# Reads `results/phase2/reconstruction.parquet` and renders cosine/L2/Wasserstein-vs-k plots
# per tile size plus the smallest-k table. See `docs/spec.md` Phase 3. Stub at Phase 0.
