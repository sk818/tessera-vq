# %% [markdown]
# # 04 — Downstream linear probes (plotting only)
#
# Reads `results/phase4/downstream.parquet` and renders the probe-raw vs probe-reconstructed
# table and the accuracy-gap vs bytes/pixel plot. See `docs/spec.md` Phase 5. Stub at Phase 0.
