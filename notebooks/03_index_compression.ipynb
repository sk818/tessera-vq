# %% [markdown]
# # 03 — Index map compression (plotting only)
#
# Reads `results/phase3/compression.parquet` and renders bytes/pixel by pipeline (faceted by k)
# and the biome x pipeline heatmap at k=16. See `docs/spec.md` Phase 4. Stub at Phase 0.
